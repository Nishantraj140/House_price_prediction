# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Reading and Analysing the Data

# %%
house_data = pd.read_csv('C:/Users/HP/Desktop/kc_house_data.csv')

# %%
house_data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Removing unecessary features

# %%
house_data=house_data.drop(['waterfront','view','id'],axis=1)

# %%
house_data.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0         3       1.00         1180      5650
# 1  20141209T000000  538000.0         3       2.25         2570      7242
# 2  20150225T000000  180000.0         2       1.00          770     10000
# 3  20141209T000000  604000.0         4       3.00         1960      5000
# 4  20150218T000000  510000.0         3       2.00         1680      8080
#
#    floors  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0          3      7        1180              0      1955
# 1     2.0          3      7        2170            400      1951
# 2     1.0          3      6         770              0      1933
# 3     1.0          5      7        1050            910      1965
# 4     1.0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 18 columns):
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# dtypes: float64(5), int64(12), object(1)
# memory usage: 3.0+ MB

# %% [markdown]
# # Exploratory Data Analysis - Visualizations

# %% [markdown]
# ### 1) HEATMAP FOR CORRELATION ANALYSIS

# %%
plt.figure(figsize=(15,15))
sns.heatmap(house_data.corr(),annot=True,cmap='coolwarm')
plt.savefig('heatmap.png')

# %% [markdown]
# ### 2) JOINTPLOT BETWEEN PRICE AND SQUARE FEET OF HOUSE, SQUARE FEET ABOVE, SQUARE FEET BASEMENT

# %%
sns.jointplot(x='sqft_living',y='price',data=house_data)

# %%
sns.jointplot(x='sqft_above',y='price',data=house_data,color='green')

# %%
sns.jointplot(x='sqft_basement',y='price',data=house_data,color='red')

# %% [markdown]
# ### 2) BARPLOT BETWEEN NUMBER OF BEDROOMS AND PRICES

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='bedrooms',y='price',data=house_data)
plt.title(" BARPLOT BETWEEN NUMBER OF BEDROOMS AND PRICES")
# Out:
# Text(0.5, 1.0, ' BARPLOT BETWEEN NUMBER OF BEDROOMS AND PRICES')

# %% [markdown]
# ### 3) COUNTPLOT OF NUMBER OF OF BEDROOMS

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=house_data,x='bedrooms',palette='rainbow')
plt.title(" COUNTPLOT OF NUMBER OF OF BEDROOMS")
plt.tight_layout()
plt.savefig("countplot")

# %% [markdown]
# ### 4) LINEAR MODEL PLOT BETWEEN NUMBER OF BATHROOMS AND SQUARE FEET OF AREA ABOVE BASEMENT, BASED ON THE GRADE OF THE HOUSE

# %%
plt.figure(figsize=(20,5))
sns.lmplot(x='bathrooms',y='sqft_above',data=house_data,hue='grade')
plt.title("LINEAR MODEL PLOT BETWEEN NUMBER OF BATHROOMS AND SQUARE FEET OF AREA ABOVE BASEMENT, BASED ON THE GRADE OF THE HOUSE")
#plt.tight_layout()
plt.savefig("lm1")

# %% [markdown]
# ### 5) LINEAR MODEL PLOT BETWEEN AREA OF THE HOUSE IN SQUARE FEET VERSUS PRICE, BASED ON THE CONDITION OF THE HOUSE

# %%
plt.figure(figsize=(20,5))
sns.lmplot(x='sqft_living',y='price',data=house_data,hue='condition')
plt.title(" LINEAR MODEL PLOT BETWEEN AREA OF THE HOUSE IN SQUARE FEET VERSUS PRICE, BASED ON THE CONDITION OF THE HOUSE")
#plt.tight_layout()
plt.savefig("lm2")

# %% [markdown]
# ### 6) BARPLOT OF CONDITION VERSUS PRICE

# %%
sns.barplot(x='condition',y='price',data=house_data)
plt.title("BARPLOT OF CONDITION VERSUS PRICE")
# Out:
# Text(0.5, 1.0, 'BARPLOT OF CONDITION VERSUS PRICE')

# %% [markdown]
# ### 7) NORMAL DISTRIBUTION OF PRICES

# %%
plt.figure(figsize=(12,4))
sns.distplot(house_data['price'],bins=30,color='purple',hist_kws=dict(edgecolor="k", linewidth=2))
plt.title("NORMAL DISTRIBUTION OF PRICES")
# Out:
# Text(0.5, 1.0, 'NORMAL DISTRIBUTION OF PRICES')

# %% [markdown]
# ## SUPERVISED LEARNING ALGORITHM - LINEAR REGRESSION

# %%
house_data.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'condition', 'grade', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15',
#        'sqft_lot15'],
#       dtype='object')

# %%
X=house_data[['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'condition', 'grade', 'sqft_above',
       'sqft_basement', 'yr_built','yr_renovated', 'zipcode', 'lat', 'long',
       'sqft_living15', 'sqft_lot15']]

# %%
y=house_data['price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lr.predict(X_test)

# %% [markdown]
# #### NUMPY ARRAY OF PREDICTED PRICES

# %%
y_pred
# Out:
# array([ 473740.78735661,  783267.38308885, 1173698.76233523, ...,
#         483411.1107788 , 1426231.49820735,  437249.47884917])

# %% [markdown]
# #### PERFORMANCE EVALUATION USING MEAN AVERAGE ERROR, MEAN SQUARE ERROR AND ROOT MEAN SQUARE ERROR

# %%
from sklearn import metrics
print("MAE:", metrics.mean_absolute_error(y_test,y_pred))
print("MSE:", metrics.mean_squared_error(y_test,y_pred))
print("RMSE:", np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print(metrics.explained_variance_score(y_test,y_pred))
# Out:
# MAE: 132985.76212631803
# MSE: 50615004166.26768
# RMSE: 224977.78593956266
# 0.6617093347208445

# %% [markdown]
# ### NORMAL DISTRIBUTION OF ERROR (TEST PRICE- PREDICTED PRICE)

# %%
plt.figure(figsize=(12,5))
sns.distplot((y_test-y_pred),bins=50,hist_kws=dict(edgecolor="k", linewidth=2));
plt.xlabel("PRICE")
plt.title("NORMAL DISTRIBUTION OF ERROR (TEST PRICE- PREDICTED PRICE)")
plt.savefig("lr1")

# %% [markdown]
# ### LINEAR REGRESSION CURVE

# %%
plt.figure(figsize=(12,5))
sns.regplot(y_test,y_pred,house_data,color='purple')
plt.xlabel("TEST PRIICES")
plt.ylabel("PREDICTED PRICES")
plt.title("LINEAR REGRESSION CURVE")
plt.savefig("lr2")
